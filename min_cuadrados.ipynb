# %% [markdown]
# # Mínimos cuadrados
# ## Prueba 02
# ### Kevin Eduardo Garcia Rodriguez
# Interpole los siguientes conjuntos de datos con la función correspondiente.

# %% [markdown]
# La ecuación de la línea es:
#
# $ y(x) = a_1 x + a_0 $
#
# Al realizar el proceso de mínimos cuadrados queda el siguiente sistema de ecuaciones:
#
#
# $( \sum_i (y_i - a_1 x_i - a_0) , \sum_i (y_i - a_1 x_i - a_0)x_i ) = 0$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
def der_parcial_cuadA(xs: list, ys: list) -> tuple[float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto a 
    La ecuación es de la forma:
    c_2 * a_2 + c_1 * a_1 + c_0 * a_0 = c_ind

    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_2``: coeficiente del parámetro a_2.

    ``c_1``: coeficiente del parámetro a_1.

    ``c_0``: coeficiente del parámetro a_0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi**2 * yi

        # coeficiente del parámetro a_2
        c_2 += xi**4

        # coeficiente del parámetro a_1
        c_1 += xi**3

        # coeficiente del parámetro a_0
        c_0 += xi**2

    return (c_2, c_1, c_0, c_ind)

# %%
def der_parcial_cuadB(xs: list, ys: list) -> tuple[float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto a 
    La ecuación es de la forma:
    c_2 * a_2 + c_1 * a_1 + c_0 * a_0 = c_ind

    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_2``: coeficiente del parámetro a_2.

    ``c_1``: coeficiente del parámetro a_1.

    ``c_0``: coeficiente del parámetro a_0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi**2 * yi

       
        # coeficiente del parámetro a_1
        c_1 += xi**2

        # coeficiente del parámetro a_0
        c_0 += xi**1

    return (c_1, c_0, c_ind)

# %%
def der_parcial_cuadC(xs: list, ys: list) -> tuple[float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto a 
    La ecuación es de la forma:
    c_2 * a_2 + c_1 * a_1 + c_0 * a_0 = c_ind

    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_2``: coeficiente del parámetro a_2.

    ``c_1``: coeficiente del parámetro a_1.

    ``c_0``: coeficiente del parámetro a_0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind +=  yi

        # coeficiente del parámetro a_0
        c_0 += xi**1

    return ( c_0, c_ind)

# %% [markdown]
# ### sss

# %% [markdown]
# # Conjunto de datos de ejemplo

# %%
xs = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys = [
    -12.7292,
    -7.5775,
    -7.7390,
    -4.1646,
    -4.5382,
    2.2048,
    4.3369,
    2.2227,
    9.0625,
    7.1860,
]

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])
# Out:
# [01-08 13:20:02][INFO] Se ajustarán 2 parámetros.
# [01-08 13:20:02][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %%
import numpy as np
import matplotlib.pyplot as plt

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])

x = np.linspace(-5, 5, 100)

y = [m * xi + b for xi in x]

plt.scatter(xs, ys, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_1 x + a_0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [01-08 13:20:04][INFO] Se ajustarán 2 parámetros.
# [01-08 13:20:04][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %% [markdown]
# ## Conjunto de datos 1

# %%
xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# %%
plt.scatter(xs1, ys1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Conjunto de datos 1")
plt.show()

# %% [markdown]
# Interpole el conjunto de datos 1 usando la función cuadrática.

# %%
import numpy as np
import matplotlib.pyplot as plt

a2, a1, a0 = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_cuadA, der_parcial_cuadB, der_parcial_cuadC])

x = np.linspace(-5, 5, 100)

y = a2*x**2 + a1*x + a0

plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red",
         label=rf"$y = {a2:.2f}x^2 + {a1:.2f}x + {a0:.2f}$")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste cuadrático por mínimos cuadrados")
plt.legend()
plt.show()
# Out:
# [01-08 13:39:54][INFO] Se ajustarán 1 parámetros.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 a2, a1, a0 = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_cuad])
#       6 x = np.linspace(-5, 5, 100)
#       8 y = a2*x**2 + a1*x + a0
#
# File c:\Users\P3E009-E\Desktop\Prueba2B\MN-prueba-02-main\src\min_cuadrados.py:70, in ajustar_min_cuadrados(xs, ys, gradiente)
#      67 for i, der_parcial in enumerate(gradiente):
#      68     assert callable(der_parcial), "Cada derivada parcial debe ser una función."
# ---> 70     Ab[i, :] = der_parcial(xs, ys)
#      72 return list(eliminacion_gaussiana(Ab))
#
# ValueError: could not broadcast input array from shape (4,) into shape (2,)

# %%
import numpy as np
import matplotlib.pyplot as plt


a2, a1, a0 = np.polyfit(xs1, ys1, 2)

x = np.linspace(-5, 5, 100)
y = a2*x**2 + a1*x + a0

plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red",
         label=rf"$y = {a2:.2f}x^2 + {a1:.2f}x + {a0:.2f}$")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste cuadrático por mínimos cuadrados")
plt.legend()
plt.show()

# %%
x_eval = 2.25
y_eval = a2*x_eval**2 + a1*x_eval + a0

print(f"y(2.25) = {y_eval}")
# Out:
# y(2.25) = 7.082840911009484

# %%
x_eval = -2.25
y_eval = a2*x_eval**2 + a1*x_eval + a0

print(f"y(-2.25) = {y_eval}")
# Out:
# y(-2.25) = 12.137803994099428

# %% [markdown]
# ## Conjunto de datos 2

# %%
xs2 = [
    0.0003,
    0.0822,
    0.2770,
    0.4212,
    0.4403,
    0.5588,
    0.5943,
    0.6134,
    0.9070,
    1.0367,
    1.1903,
    1.2511,
    1.2519,
    1.2576,
    1.6165,
    1.6761,
    2.0114,
    2.0557,
    2.1610,
    2.6344,
]
ys2 = [
    1.1017,
    1.5021,
    0.3844,
    1.3251,
    1.7206,
    1.9453,
    0.3894,
    0.3328,
    1.2887,
    3.1239,
    2.1778,
    3.1078,
    4.1856,
    3.3640,
    6.0330,
    5.8088,
    10.5890,
    11.5865,
    11.8221,
    26.5077,
]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(xs2, ys2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Conjunto de datos 2")
plt.show()

# %% [markdown]
# Interpole el conjunto de datos 2 usando la función exponencial.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ajuste exponencial: y = A * e^(B x)

B, lnA = np.polyfit(xs2, np.log(ys2), 1)
A = np.exp(lnA)

x = np.linspace(min(xs2), max(xs2), 100)
y = A * np.exp(B * x)

plt.scatter(xs2, ys2, label="Datos")
plt.plot(x, y, color="red",
         label=rf"$y = {A:.2f}e^{{{B:.2f}x}}$")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste exponencial por mínimos cuadrados")
plt.legend()
plt.show()

# %%
x_eval = 5
y_eval = A * np.exp(B * x_eval)

plt.scatter(xs2, ys2, label="Datos")
plt.plot(x, y, color="red",
         label=rf"$y = {A:.2f}e^{{{B:.2f}x}}$")
plt.scatter(x_eval, y_eval, color="green", zorder=5,
            label=f"y(5) = {y_eval:.2f}")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste exponencial por mínimos cuadrados")
plt.legend()
plt.show()

# %%
x_eval = 1
y_eval = A * np.exp(B * x_eval)

plt.scatter(xs2, ys2, label="Datos")
plt.plot(x, y, color="red",
         label=rf"$y = {A:.2f}e^{{{B:.2f}x}}$")
plt.scatter(x_eval, y_eval, color="green", zorder=5,
            label=f"y(1) = {y_eval:.2f}")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste exponencial por mínimos cuadrados")
plt.legend()
plt.show()


print(f"y(1) = {y_eval}")
# Out:
# y(1) = 2.2445646053759503
